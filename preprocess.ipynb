# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the path specified.
# WARNING: You are using pip version 21.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\dev\resnet18-vae\venv39\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
from pathlib import Path
cxr8_data_path = Path('D:\\') / 'data' / 'cxr8'
df = pd.read_csv(cxr8_data_path / 'Data_Entry_2017_v2020.csv')
df
# Out:
#              Image Index          Finding Labels  Follow-up #  Patient ID
# 0       00000001_000.png            Cardiomegaly            0           1  \
# 1       00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2       00000001_002.png   Cardiomegaly|Effusion            2           1
# 3       00000002_000.png              No Finding            0           2
# 4       00000003_001.png                  Hernia            0           3
# ...                  ...                     ...          ...         ...
# 112115  00030801_001.png          Mass|Pneumonia            1       30801
# 112116  00030802_000.png              No Finding            0       30802
# 112117  00030803_000.png              No Finding            0       30803
# 112118  00030804_000.png              No Finding            0       30804
# 112119  00030805_000.png              No Finding            0       30805
#
#         Patient Age Patient Gender View Position  OriginalImage[Width
# ...

# %%
import shutil

for img_name in df[df['Finding Labels'].str.contains('No Finding')]['Image Index']:
    src = cxr8_data_path / 'no_finding' / img_name
    dst = cxr8_data_path / 'filtered' / img_name
    shutil.copyfile(src, dst)
